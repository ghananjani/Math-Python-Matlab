# %%
# colab is built in with the basic functions like add,subtract,multiply,divide

# %% [markdown]
# Set up a proportion :
# n1/d1 = n2/d2

# %%
#put a zero in for the unknown value

n1 =1
d1 = 2
n2 = 0
d2 = 16

if n2==0:
  answer = d2 * n1/d1
  print("n2=", answer)
# Out:
# n2= 8.0

# %%
#put a zero in for the unknown value

n1 =1
d1 = 2
n2 = 4
d2 = 0

if d2==0:
  answer = n2*d1/n1
  print("d2=", answer)
# Out:
# d2= 8.0

# %%
#ep1

a = 5/3
b = 19/5
c = -7

print(a+b+c)
# Out:
# -1.5333333333333332

# %%
#ep2

x = (1+2/3+3+4/5_7)
#storing as a variable and printing the answer
print(x)
# Out:
# 4.7368421052631575

# %%
x = 0.66666666

# %%
10*x
# Out:
# 6.666666599999999

# %%
x
# Out:
# 0.66666666

# %%
#converting money

# 1 US dollar = 1.29 Can
#similar way as above (3), we can find the money conversion

# 1 mile = 1.6 km

# %%
#solving for x. the variable eq is the equation set equal to zero. This will print an array of solutions

import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

# put the equation here
eq = x - 2

print ("x = ", solve(eq,x))
# Out:
# x =  [2]

# %%
x = symbols('x')

# put the equation here
eq = x**2 - 2

print ("x = ", solve(eq,x))
# Out:
# x =  [-sqrt(2), sqrt(2)]

# %%
x = symbols('x')

# put the equation here
eq = x**2 - 4

print ("x = ", solve(eq,x))
# Out:
# x =  [-2, 2]

# %%
x = symbols('x') # stays same

# put the equation here
eq = 2*x - 2

print ("x = ", solve(eq,x)) # stays same
# Out:
# x =  [1]

# %%
x = symbols('x') # stays same

# put the equation here
eq = 2*x +1

solve(eq,x) # stays same, solve function
# Out:
# [-1/2]

# %%
x = symbols('x') # stays same

# put the equation here
eq = 2*x**2 +1

solve(eq,x) # stays same, solve function
# Out:
# [-sqrt(2)*I/2, sqrt(2)*I/2]

# %%
x = symbols('x') # stays same

# put the equation here
eq = 2*x**2 - 4

solve(eq,x) # stays same, solve function
# Out:
# [-sqrt(2), sqrt(2)]

# %%
# Prompt for someone to enter the equation and solve then

x = symbols('x')
eq = input('enter the equation: 0 = ')

print ("x = " , solve(eq,x))
# Out:
# enter the equation: 0 = 3*x - 6
# x =  [2]

# %%
#doing more with the solution

x = symbols('x')

#put the equation here
eq = 2*x - 4

solution = solve(eq,x)
for s in solution:
  # for multiple solutions
  print("x = ", s)
# Out:
# x =  2

# %%
x = symbols('x')

#put the equation here
eq = input('enter the equation: 0 = ')
solution = solve(eq,x)
for s in solution:
  # for multiple solutions
  print("x = ", s)
# Out:
# enter the equation: 0 = (x+1) * (x - 2) * (x + 7)
# x =  -7
# x =  -1
# x =  2

# %%
import sympy
from sympy import *

var('x y')

#first equation set equal to zero, ready to solve
first = 2*x +10
#by default it is zero

#sympy syntax for equation to zero, ready to factor
eq1 = Eq(first,y)

#sympy solve for x
sol = solve(eq1,x)

#show factored results
print("x = ", sol[0])
# Out:
# x =  y/2 - 5

# %%
from sympy import *


var('x y')

# First equation set equal to zero, ready to solve
first = 2*x - y


# Sympy syntax for equation equal to zero, ready to factor
eq1 = Eq(first,0)

# Sympy solve for x
sol = solve(eq1,x)

# Show factored results
print("x = ", sol[0])
# Out:
# x =  y/2

# %%
import sympy
from sympy import *

var('x y')

# Equation set equal to zero, ready to solve
#eq = x**2-4
eq = x**3 - 2*x**2 - 5*x + 6

sympy.factor(eq)
# Out:
# (x - 3)*(x - 1)*(x + 2)

# %%
# converts string input (including fractions) to float
def string_frac(in_string):
    if "/" in in_string:
        nd = in_string.split("/")
        n = float(nd[0])
        d = float(nd[1])
        ans = n/d
        return ans
    else:
        ans = float(in_string)
        return ans


# Simplest one-step addition
def one_step_add():
    import random
    # Display problem
    a = random.randint(-4,10)
    b = random.randint(2,24)
    print("x + ", a, " = ", b)
    ans = float(input("x = "))
    answer = b-a
    # Test input
    if ans==answer:
        print("Correct! \n")
    else:
        print("Try again")
        print("The correct answer is ", answer, "\n")


# One-step additon with negaive numbers
def one_step_subtract():
    import random
    a = random.randint(-19,-1)
    b = random.randint(2,24)
    print(a, " + x = ", b)
    ans = float(input("x = "))
    # test
    answer = b-a
    if ans==answer:
        print("Correct! \n")
    else:
        print("Try again")
        print("The correct answer is ", answer, "\n")

# One-step multiply
def one_step_mult():
    # Uses string_frac(<input string>)
    import random
    a = random.randint(1,11)
    b = random.randint(2,24)
    print(a, "x = ", b)
    ans_in = (input("x = "))
    answer = b/a
    # test
    if string_frac(ans_in)==answer:
        print("Correct! \n")
    else:
        print("Try again")
        print("The correct answer is ", answer, "\n")

# %%
print(3/4)
# Out:
# 0.75

# %%
frac = float(input("fraction ="))
print(frac)
# Out:
# fraction =5
# 5.0
