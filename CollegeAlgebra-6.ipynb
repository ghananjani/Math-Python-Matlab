# %%
#factoring
'''
6 = 2*3
15 = 5*3

6/15 = 2'5

6/24 = 3/12 = 1/4

factor and remove the fraction

4x + 16
4(x+4)



root 24 = root = 6*4
= 2 root 6

# %% [markdown]
# The modulus (%) finds the remainder

# %%
print(5%3)
# Out:
# 2

# %%
print(31%10)
# Out:
# 1

# %% [markdown]
# Use the modulus in a loop to find the factors

# %%
number = 12

# find all the factors

for test_factor in range(1,number+1) :
  if number%test_factor==0:
    print(test_factor)
# Out:
# 1
# 2
# 3
# 4
# 6
# 12

# %% [markdown]
# Reduce fractions to lowest terms

# %%
numerator = 12
denominator = 24
factor = 1

#find the greatest common factor

for test_factor in range(1,denominator+1) :
  if numerator%test_factor==0 and denominator%test_factor==0:
      factor = test_factor

# divide out the gcf

n = int(numerator/factor)
d = int(denominator/factor)

print("original:" , numerator, "/" , denominator)
print("reduced:" , n, "/" , d)
# Out:
# original: 12 / 24
# reduced: 1 / 2

# %% [markdown]
# you can use this code to the decimal to fraction code

# %%
# Get the decimal number to convert
digits = input("Enter a decimal number to convert: ")

# Convert to fraction
exponent = int(len(digits))-1
n = float(digits)
numerator = int(n * 10**exponent)
denominator = 10**exponent

# Reduce that fraction
factor = 1
for test_factor in range(1,denominator+1):
    if numerator%test_factor==0 and denominator%test_factor==0:
        factor = test_factor

# Divide out greatest common factor
num = int(numerator/factor)
den = int(denominator/factor)

# Output
print("The decimal is ", n)
print("The fraction is ", num, "/", den)
# Out:
# Enter a decimal number to convert: 4.5
# The decimal is  4.5
# The fraction is  9 / 2

# %%
# factoring square roots

import math
print(math.sqrt(24))
# Out:
# 4.898979485566356

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
'''
we knwo

root 24 = root = 6*4
= 2 root 6

because 4 is a square number, the square root of 4 is now outside the radical

'''

import math
# number to factor

n = 12
# this variable will change
max_factor = 1

# the key ingredient

upper_limit = math.floor(math.sqrt(n)) + 1

#find the square factors
for maybe_factor in range(1,upper_limit) :
  if n % (maybe_factor**2) == 0:
    max_factor = maybe_factor

# results so far
print("n = ", n)
print("Square rooted factor = ", max_factor)
print("Square factor = ", max_factor**2)
print("integer: ", n/(max_factor**2))
# Out:
# n =  12
# Square rooted factor =  2
# Square factor =  4
# integer:  3.0

# %%
import math
# number to factor

n = 24
# this variable will change
max_factor = 1

# the key ingredient

upper_limit = math.floor(math.sqrt(n)) + 1

#find the square factors
for maybe_factor in range(1,upper_limit) :
  if n % (maybe_factor**2) == 0:
    max_factor = maybe_factor

# results so far
print("n = ", n)
print("Square rooted factor = ", max_factor)
print("Square factor = ", max_factor**2)
print("integer: ", n/(max_factor**2))
# Out:
# n =  24
# Square rooted factor =  2
# Square factor =  4
# integer:  6.0

# %%
# using sympy

import math
import sympy
from sympy import symbols

n = 24

# Use these variables
upper_limit = math.floor(math.sqrt(n)) + 1
max_factor = 1
other_factor = 1
square_root = 1

# Slightly different variable strategy
for maybe_factor in range(1, upper_limit):
    if n % (maybe_factor**2) == 0:
        max_factor = maybe_factor**2

# Divide out the greatest square factor
other_factor = n/max_factor

# Output variables
square_root = int(math.sqrt(max_factor))
other_factor = int(other_factor)
output = square_root*sympy.sqrt(other_factor)

# Sympy output without print statement - must be last line
output
# Out:
# 2*sqrt(6)
